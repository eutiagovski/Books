# %%
import random
import import_ipynb

from typing import List, Dict
from collections import Counter
import math

import matplotlib.pyplot as plt

# %%
def bucketize(point: float, bucket_size: float) -> float:
    """Coloque o ponto perto do próximo mínimo multiplo de bucket_size"""
    return bucket_size * math.floor(point / bucket_size)

def make_histogram(points: List[float], bucket_size: float) -> Dict[float, int]:
    """Coloca os pontos em buckets e conta o número de pontos em cada bucket"""
    return Counter(bucketize(point, bucket_size) for point in points)

def plot_histogram(points: List[float], bucket_size: float, title: str = ""):
    histogram = make_histogram(points, bucket_size)
    plt.bar(histogram.keys(), histogram.values(), width=bucket_size)
    plt.title(title)
    plt.show()

# %%
# exemplo de um conjunto de dados

from probability import inverse_normal_cdf

# %%
random.seed(0)

# uniforme entre -100 e 100
uniform = [200 * random.random() - 100 for _ in range(10000)]

# distribuição normal com média 0 e desvio 57
normal = [57 * inverse_normal_cdf(random.random()) for _ in range(10000)]

# plot_histogram(uniform, 10, "Uniform Histogram")

# %%
# plot_histogram(normal, 10, "Normal Histogram")

# %%
# dados com mais de uma dimensão

def random_normal() -> float:
    """Retorna um ponto aleatório de uma distribuição normal padrão"""
    return inverse_normal_cdf(random.random())

# xs = [random_normal() for _ in range(1000)]
# ys1 = [x + random_normal() / 2 for x in xs]
# ys2 = [-x + random_normal() / 2 for x in xs]

# plt.scatter(xs, ys1, marker='.', color='black', label='ys1')
# plt.scatter(xs, ys2, marker='.', color='gray', label='ys2')
# plt.xlabel('xs')
# plt.ylabel('ys')
# plt.legend(loc=9)
# plt.title('Very Different Joint Distributions')
# plt.show()

# %%
from statistics import correlation

# print(correlation(xs, ys1))
# print(correlation(xs, ys2))

# %%
# muitas dimensões
# matriz de correlação

from linear_algebra import Matrix, Vector, make_matrix

def correlation_matrix(data: List[Vector]) -> Matrix:
    """Retorna a matrix len(data) x len(data), na qual a entrada (i, j) é a correlação entre data[i] e data[j]"""
    def correlation_ij(i: int, j: int) -> float:
        return correlation(data[i], data[j])
    
    return make_matrix(len(data), len(data), correlation_ij)

# %%
# corr_data é uma lista com quatro vetores 100-d

# corr_data = [list(col) for col in zip(*corr_rows)]

# num_vectors = len(corr_data)
# fig, ax = plt.subplots(num_vectors, num_vectors)

# for i in range(num_vectors):
#     for j in range(num_vectors):

#         # disperse a column_j no eixo x ea column_i no eixo y
#         if i != j: ax[i][j].scatter(corr_data[j], corr_data[i])

#         # a menos que i==j, neste caso, mostre o nome da série
#         else: ax[i][j].annotate("serie" + str(i), (0.5, 0.5), xcoords='axes fraction', ha='center', va='center')

#         # Em seguida, oculte os rótulos dos eixos, exceto pelos gráficos à esquerda e na parte inferior
#         if i < num_vectors - 1: ax[i][j].xaxis.set_visible(False)
#         if j > 0: ax[i][j].yaxis.set_visible(False)

# ax[-1][-1].set_xlim(ax[0][-1].get_xlim())        
# ax[0][0].set_ylim(ax[0][1].get_ylim())

# plt.show()

# %% [markdown]
# ### Usando o Named Tuple

# %%
import datetime

stock_price = {
    'closing_price': 102.06,
    'date': datetime.date(2014, 8, 29),
    'symbol': 'AAPL'
}

# os dicts tem grande propensão a erros de digitação
stock_price['cosing_price'] = 103.06

# aqui também perdemos o poder das dicas de tipo
prices: Dict[datetime.time, float] = {}

# %%
from collections import namedtuple

StockPrice = namedtuple('StockPrice', ['symbol', 'date', 'closing_price'])
price = StockPrice('MSFT', datetime.date(2018, 12, 14), 106.03)

assert price.symbol == 'MSFT'
assert price.closing_price == 106.03

# %%
from typing import NamedTuple

class StockPrice(NamedTuple):
    symbol: str
    date: datetime.date
    closing_price: float

    def is_high_tech(self) -> bool:
        """Como é uma classe, também podemos adicoinar métodos"""
        return self.symbol in ['MFST', 'GOOG', 'FB', 'AMZN', 'AAPL']
    
price = StockPrice('MFST', datetime.date(2018, 12, 14), 106.03)

assert price.symbol == 'MFST'

# %%
from dataclasses import dataclass

@dataclass
class StockPrice2:
    symbol: str
    date: datetime.date
    closing_price: float

    def is_high_tech(self) -> bool:
        """Como é uma classe, também podemos adicoinar métodos"""
        return self.symbol in ['MFST', 'GOOG', 'FB', 'AMZN', 'AAPL']
    
price2 = StockPrice2('MFST', datetime.date(2018, 12, 14), 106.03)    

assert price2.symbol == 'MFST'
assert price2.closing_price == 106.03

# %%
price2.closing_price /= 2
# assert price2.closing_price == 51.01

# %% [markdown]
# ### Limpando e Estruturando

# %%
from dateutil.parser import parse

def parse_row(row: List[str]) -> StockPrice:
    symbol, date, closing_price = row
    return StockPrice(symbol=symbol,
                      date = parse(date).date(),
                      closing_price=float(closing_price))

# testando a função
stock = parse_row(['MFST', "2018-12-14", "106.03"])

assert stock.symbol == 'MFST'
assert stock.closing_price == 106.03

# %%
from typing import Optional
import re

def try_parse_now(row: List[str]) -> Optional[StockPrice]:
    symbol, date_, closing_price_ = row

    # Os simbolos das ações devem ser em letra maiúscula
    if not re.match(r"^[A-Z]+$", symbol):
        return None
    
    try:
        date = parse(date_).date()
    except ValueError:
        return None

    try:
        closing_price = float(closing_price_)
    except ValueError:
        return None

    return StockPrice(symbol, date, closing_price)


assert try_parse_now(['MFST0', '2018-12-14', '106.03']) is None
assert try_parse_now(['MFST', '2018-12--14', '106.03']) is None
assert try_parse_now(['MFST', '2018-12-14', 'x']) is None

assert try_parse_now(['MFST', '2018-12-14', '106.03']) == stock

# %%
import csv

data: List[StockPrice] = []

# with open('./datasets/comma_delimited_stock_prices.csv') as f:
#     reader = csv.reader(f)
#     for row in reader:
#         maybe_stock = try_parse_now(row)
#         if maybe_stock is None:
#             print(f'skipping invalid row: {row}')
#         else:
#             data.append(maybe_stock)

# data

with open('./datasets/stocks.csv', "r") as f:
    reader = csv.DictReader(f)
    rows = [[row['Symbol'], row['Date'], row['Close']] for row in reader]

maybe_data = [try_parse_now(row) for row in rows]

assert maybe_data
assert all(sp is not None for sp in maybe_data)

data = [sp for sp in maybe_data if sp is not None]

# %% [markdown]
# ### Manipulando Dados

# %%
# qual o maior preço de fechamento de appl

max_appl_price = max(stock_price.closing_price
                     for stock_price in data
                     if stock_price.symbol == 'AAPL')

max_appl_price
# Out:
# 232.070007

# %%
# qual o maior preço de fechamanto de cada ação

from collections import defaultdict

max_prices: Dict[str, float] = defaultdict(lambda: float('-inf'))

for sp in data:
    symbol, closing_price = sp.symbol, sp.closing_price
    if closing_price > max_prices[symbol]:
        max_prices[symbol] = closing_price

max_prices
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'AAPL': 232.070007,
#              'MSFT': 115.610001,
#              'FB': 217.5,
#              'GOOG': 1268.329956})

# %%
# 

from typing import List
from collections import defaultdict

# Colete os preços por símbolo
prices: Dict[str, List[StockPrice]] = defaultdict(list)

for sp in data:
    prices[sp.symbol].append(sp)

prices = {symbol: sorted(symbol_prices)
          for symbol, symbol_prices in prices.items()}

# %%
def pct_change(yesterday: StockPrice, today: StockPrice) -> float:
    return today.closing_price / yesterday.closing_price - 1

class DailyChange(NamedTuple):
    symbol: str
    date: datetime.date
    pct_change: float

def day_over_day_changes(prices: List[StockPrice]) -> List[DailyChange]:
    """Presume que os preços são de uma ação e estão classificados"""
    return [DailyChange(symbol=today.symbol,
                        date=today.date,
                        pct_change=pct_change(yesterday, today))
                        for yesterday, today in zip(prices, prices[1:])]

all_changes = [change
               for symbol_prices in prices.values()
               for change in day_over_day_changes(symbol_prices)]

all_changes
# Out:
# [DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 15), pct_change=-0.05217445504710816),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 16), pct_change=-0.07339392980372261),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 17), pct_change=0.0247531010683244),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 18), pct_change=0.02898362529055043),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 19), pct_change=0.061033219335108635),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 22), pct_change=0.04867344349646352),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 23), pct_change=0.04219327130645856),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 24), pct_change=0.052631865331493),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 26), pct_change=0.09230869964521826),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 29), pct_change=0.014083596112498542),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 30), pct_change=-0.024305560956791372),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 31), pct_change=-0.02846952961583593),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 2), pct_change=0.010988307692307853),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 5), pct_change=-0.021737754252350916),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 6), pct_change=-0.044444886913265536),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 7), pct_change=-0.04263639252430562),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 8), pct_change=-0.020241629922788107),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 9), pct_change=0.053717378868856525),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 12), pct_change=-0.007842641199165223),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 13), pct_change=-0.03557262559939944),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 14), pct_change=0.0040980972857449505),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 15), pct_change=0.02040868571428578),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 16), pct_change=-0.00800127590334665),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 19), pct_change=0.06048546618229622),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 20), pct_change=-0.03041968881908641),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 21), pct_change=0.01960835986198073),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 22), pct_change=0.011539448994325907),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 23), pct_change=-0.003803738667992995),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 26), pct_change=-0.015266209660733887),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 27), pct_change=-0.007751439937627391),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 28), pct_change=-0.03125147656139249),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 29), pct_change=-0.03628983454696877),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 30), pct_change=-0.05439358778740422),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 2), pct_change=-0.05752243965872694),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 3), pct_change=0.037560522120283046),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 4), pct_change=0.03619877398115556),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 5), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 6), pct_change=0.00436653031041101),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 9), pct_change=-0.05217445504710816),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 10), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 11), pct_change=-0.032110101169937955),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 12), pct_change=-0.009478069225575592),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 13), pct_change=-0.02392405009024301),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 17), pct_change=0.024510439062098488),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 18), pct_change=0.04306157533042665),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 19), pct_change=-0.05963333860795261),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 20), pct_change=-0.05365732130798606),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 23), pct_change=0.015462917632714124),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 24), pct_change=-0.035533006467575734),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 25), pct_change=0.0631585896955249),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 26), pct_change=0.014850529948347013),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 27), pct_change=0.03414636278407035),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 3, 2), pct_change=0.0047166820930910625),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 3,

#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 15), pct_change=-0.03463175757575765),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 16), pct_change=0.008968033300654099),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 17), pct_change=-0.02222279743226241),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 20), pct_change=-0.0045451676030552335),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 21), pct_change=0.04109737561855731),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 22), pct_change=-0.017544686979912627),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 23), pct_change=0.0044640000000000235),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 24), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 27), pct_change=-0.008888322528234016),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 28), pct_change=0.013452049950981149),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 29), pct_change=-0.0265489707887977),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 30), pct_change=-0.01818067041222149),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 31), pct_change=-0.018519401920177092),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 4), pct_change=-0.009433364186182236),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 5), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 6), pct_change=0.009523200000000065),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 7), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 10), pct_change=-0.0047166820930910625),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 11), pct_change=0.01895826167454384),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 12), pct_change=-0.027907257804051122),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 13), pct_change=0.05263033795051841),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 14), pct_change=0.013637539174579771),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 17), pct_change=0.02690610886999556),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 18), pct_change=-0.034934198814072226),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 19), pct_change=-0.022624993918557434),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 20), pct_change=0.004629331961679473),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 21), pct_change=-0.009216000000000002),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 24), pct_change=-0.009303808414476866),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 25), pct_change=-0.018778157771860537),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 26), pct_change=-0.014355287470151246),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 27), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 9, 28), pct_change=-0.02427031388301104),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 1), pct_change=-0.024876242864880105),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 2), pct_change=0.01020342857142853),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 3), pct_change=0.01515281787656897),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 4), pct_change=0.009949605604231415),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 5), pct_change=-0.019705379310344884),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 8), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 9), pct_change=-0.01004961773631452),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 10), pct_change=-0.030457187559695398),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 11), pct_change=-0.005235270524160396),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 12), pct_change=-0.04210494049850633),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 15), pct_change=0.05494399999999988),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 16), pct_change=-0.005208005208005129),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 17), pct_change=0.04188450974459279),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 18), pct_change=0.030151104467397438),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 19), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 22), pct_change=-0.009755479261957856),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 23), pct_change=0.02463117241379309),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 24), pct_change=0.009614763313991803),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 25), pct_change=-0.03809493333333336),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 26), pct_change=-0.0247531010683244),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 29), pct_change=0.005075818907880336),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 30), pct_change=0.010102632793621114),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 31), pct_change=-0.005001915198161511),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 1), pct_change=0.005027060126610916),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 2), pct_change=-0.005001915198161511),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 5), pct_change=-0.005024808868157149),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 6), pct_change=0.06060674625082574),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 7), pct_change=-0.01904853333333334),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 8), pct_change=-0.03883467697212606),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 9), pct_change=-0.06060448362310056),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 12), pct_change=0.03763436975376888),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 13), pct_change=-0.025907373190592553),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 14), pct_change=0.010637613399961499),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 15), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 16), pct_change=-0.02105129130148753),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 19), pct_change=-0.05914075615577863),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 20), pct_change=0.03428608),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 21), pct_change=0.022098025335504756),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 23), pct_change=0.027027746969337407),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 26), pct_change=0.010525645650743654),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 27), pct_change=0.02604235937569288),
#  ...]

# %%
# encontrando o maior e o menor valor

max_change = max(all_changes, key=lambda change: change.pct_change)

assert max_change.symbol == 'AAPL'
assert max_change.date == datetime.date(1997, 8, 6)
assert 0.33 < max_change.pct_change < 0.34

min_change = min(all_changes, key=lambda change: change.pct_change)

assert min_change.symbol == 'AAPL'
assert min_change.date == datetime.date(2000, 9, 29)
assert -0.52 < min_change.pct_change < -0.51

# %%
changes_by_month: List[DailyChange] = {month: [] for month in range(1, 13)}

for change in all_changes:
    changes_by_month[change.date.month].append(change)

avg_daily_change = {
    month: sum(change.pct_change for change in changes) / len(changes)
    for month, changes in changes_by_month.items()
}
avg_daily_change
# Out:
# {1: 0.0021865911307884013,
#  2: 0.00014320928359588448,
#  3: 0.0009950657322022312,
#  4: 0.0017246603289960414,
#  5: 0.001045801424244935,
#  6: -0.00038890680439638084,
#  7: 0.0008653144845121465,
#  8: 0.0012329314091353012,
#  9: -4.63670330797049e-06,
#  10: 0.002905423893850083,
#  11: 0.0008081709427041247,
#  12: 0.0009192394682663616}

# %% [markdown]
# ### Redimensionamento

# %%
from linear_algebra import distance

# dados são sensíveis a escala
# quando clusterizamos, queremos encontrar os pontos mais próximos
# em dados absolutos, o vizinho mais próximo de B é A

a_to_b = distance([63, 150], [67, 160])
a_to_b

a_to_c = distance([63, 150], [70, 171])
a_to_c

b_to_c = distance([67, 160], [70, 171])
b_to_c
# Out:
# 11.40175425099138

# %%
# considerando os centimetros o vizinho mais próximo de B é C

a_to_b = distance([160, 150], [170.2, 160])
a_to_b

a_to_c = distance([160, 150], [177.8, 171])
a_to_c

b_to_c = distance([170.2, 160], [177.8, 171])
b_to_c
# Out:
# 13.370115930686627

# %%
from typing import Tuple

from linear_algebra import vector_mean
from statistics_ import standard_deviation

def scale(data: List[Vector]) -> Tuple[Vector, Vector]:
    """Retorna a média e o desvio padrão de cada posição"""
    dim = len(data[0])

    means = vector_mean(data)
    stdevs = [standard_deviation([vector[i] for vector in data]) for i in range(dim)]

    return means, stdevs

vectors = [[-3, -1, 1], [-1, 0, 1], [1, 1, 1]]
means, stdevs = scale(vectors)

assert means == [-1, 0, 1]
assert stdevs == [2, 1, 0]

# %%
def rescale(data: List[Vector]) -> List[Vector]:
    """
    Redimensiona os dados de entrada para que cada posição tenha média 0 e desvio-padrão 1.
    (Deixa a posição como está se o desvio-padrão for 0)
    """
    dim = len(data[0])
    means, stdevs = scale(data)

    # Faça uma cópia de cada vetor
    rescaled = [v[:] for v in data]

    for v in rescaled:
        for i in range(dim):
            if stdevs[i] > 0:
                v[i] = (v[i] - means[i]) / stdevs[i]

    return rescaled

means, stdevs = scale(rescale(vectors))
assert means == [0, 0, 1]
assert stdevs == [1, 1, 0]

# %% [markdown]
# ### TQDM

# %%
# !python -m pip install tqdm
# Out:
# Requirement already satisfied: tqdm in e:\tiago\projetos\books\data-science-from-scratch\.venv\lib\site-packages (4.66.2)
# Requirement already satisfied: colorama in e:\tiago\projetos\books\data-science-from-scratch\.venv\lib\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tqdm

for i in tqdm.tqdm(range(100)):
    # faça algo devagar
    _ = [random.random() for _ in range(100000)]
# Out:
# 100%|██████████| 100/100 [00:07<00:00, 13.47it/s]

# %%
from typing import List

def primes_up_to(n: int) -> List[int]:
    primes = [2]

    with tqdm.trange(3, n) as t:
        for i in t:
            # i é primo se não for divisivel por nenhum numero primo menor
            i_is_prime = not any(i % p == 0 for p in primes)
            if i_is_prime:
                primes.append(i)

            t.set_description(f"{len(primes)} primes")

    return primes

# my_primes = primes_up_to(100_000)
# Out:
# 885 primes:   7%|▋         | 6868/99997 [00:33<07:32, 205.71it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 17
#      13             t.set_description(f"{len(primes)} primes")
#      15     return primes
# ---> 17 my_primes = primes_up_to(100_000)
#
# Cell In[78], line 13, in primes_up_to(n)
#      10         if i_is_prime:
#      11             primes.append(i)
# ---> 13         t.set_description(f"{len(primes)} primes")
#      15 return primes
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\tqdm\std.py:1394, in tqdm.set_description(self, desc, refresh)
#    1392 self.desc = desc + ': ' if desc else ''
#    1393 if refresh:
# -> 1394     self.refresh()
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\tqdm\std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\tqdm\std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\tqdm\std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\tqdm\std.py:453, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
#     452     fp.write(str(s))
# --> 453     fp_flush()
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\tqdm\utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File e:\Tiago\Projetos\Books\data-science-from-scratch\.venv\Lib\site-packages\ipykernel\iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
from linear_algebra import subtract

# traduzindo os dados para que cada dimensão tenha média 0

def de_mean(data: List[Vector]) -> List[Vector]:
    """Centraliza novamente os dados para que todas as dimensões tenham média 0"""
    mean = vector_mean(data)
    return [subtract(vector, mean) for vector in data]

# %%
from linear_algebra import magnitude

# Qual é a direção que captura a maior variação nos dados?
def direction(w: Vector) -> Vector:
    mag = magnitude(w)
    return [w_i / mag for w_i in w]

# %%
from linear_algebra import dot

# Qual a variação no conjunto de dados determinada por w?
def diretional_variance(data: List[Vector], w: Vector) -> float:
    """Retorna a variação de x na direção w"""
    w_dir = direction(w)
    return sum(dot(v, w_dir) ** 2 for v in data)

# %%
def diretional_variance_gradient(data: List[Vector], w: Vector) -> Vector:
    """
    O gradiente da variação direcional em relação a w
    """
    w_dir = direction(w)
    return [sum(2 * dot(v, w_dir) * v[i] for v in data) for i in range(len(w))]

# %%
from gradient_descent import gradient_step

def first_principal_component(data: List[Vector],
                                n: int = 100,
                                step_size: float = 0.1) -> Vector:
    # Começe com um valor aleatório
    guess = [1.0 for _ in data[0]]

    with tqdm.trange(n) as t:
        for _ in t:
            dv = diretional_variance(data, guess)
            gradient = diretional_variance_gradient(data, guess)
            guess = gradient_step(guess, gradient, step_size)
            t.set_description(f"dv: {dv:.3f}")
    
    return direction(guess)
# Out:
# importing Jupyter notebook from gradient_descent.ipynb

# %%
import import_ipynb
from linear_algebra import scalar_multiply, dot, subtract

def project(v: Vector, w: Vector) -> Vector:
    """Retorne a projeção de v na direção w"""
    projection_length = dot(v, w)
    return scalar_multiply(projection_length, w)

# %%
def remove_projection_from_vector(v: Vector, w: Vector) -> Vector:
    """Projete v em w e subtraia o resultado de v"""
    return subtract(v, project(v, w))

def remove_projection(data: List[Vector], w: Vector) -> List[Vector]:
    return [remove_projection_from_vector(v, w) for v in data]

# %%
def pca(data: List[Vector], num_components: int) -> List[Vector]:
    components: List[Vector] = []
    for _ in range(num_components):
        component = first_principal_component(data)
        components.append(component)
        data = remove_projection(data, component)

    return components

def transform_vector(v: Vector, components: List[Vector]) -> Vector:
    return [dot(v, w) for w in components]

def transform(data: List[Vector], components: List[Vector]) -> List[Vector]:
    return [transform_vector(v, components) for v in data]
